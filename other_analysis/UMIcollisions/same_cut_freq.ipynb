# %% [markdown]
# # How to compute required input
#
# ```
# # in case you want to resort the BAM file
# samtools sort -@ 7 P_6_2_J_1.sorted.bam -o P_6_2_J_1.resorted.bam --write-index
# ```
#
# ### Starting from a BAM file you can run this
# ```
# samtools sort -@ 7 P_6_2_J_1.sorted.bam -o P_6_2_J_1.resorted.bam --write-index
#  for file in $(ls *.bam | cut -d '.' -f 1); do echo ${file}; samtools view -@ 15 ${file}.sorted.bam | awk 'BEGIN{OFS="\t"} !/^@/ { if ($8 < $4) { print $1, $3, $8, $4    } else {        print $1,  $3, $4, $8    }}' | sort | uniq | cut -f 2- | sort | uniq -c | sort -nr | gzip > ${file}.sorted.read_counts_custom.tsv.gz; done;
#
#
# samtools view IA010_C_1_H_1.sorted.bam | awk 'BEGIN{OFS="\t"} !/^@/ { if ($8 < $4) { print $1, $3, $8, $4    } else {        print $1,  $3, $4, $8    }}' | sort | uniq | cut -f 2- | sort | uniq -c | sort -nr | gzip > IA010_C_1_H_1.sorted.read_counts_custom.tsv.gz
# ```

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sample = "IA010_C_1_H_1"
run = "/data/bbg/nobackup2/prominent/colon_duplex/iarc_pilot/deepUMI/2025-10-27_NOV69-70_plus_all_colon_DU5_set1"

# %%
# sample = "IA011_C_1_H_2"
# run = "/data/bbg/nobackup2/prominent/colon_duplex/iarc_pilot/deepUMI/2025-11-01_NOV70_colon_redo_only_new_samples_DU7"
sample = "C_11_2_H_1"
run = "/data/bbg/nobackup2/prominent/colon_duplex/iarc_pilot/deepUMI/2025-09-04_deepUMI_NOV66_colon"

# %%
sample = "P_6_2_J_1"
run = "/data/bbg/nobackup/prominent/pancreas/2025-10-28_pilot_samples"

# %%
sample = [
#             "TS_DNA_TS_FEZ_TS_Adapters_idt_v2",
#             "TS_DNA_IDT_EZF",
#             "TS_DNA_75uM_IDT_idt_v3_speedvac",
            "Cord_Blood_3_Ultrashear",
            # "Cord_Blood_3_IDT_EZF_FPGUDG_338",
            # "Cord_Blood_3_IDT_EZF_354",
            "Cord_Blood_3_bufferR1_1",
            # "Cord_Blood_3_3uM_KapaPCR",
            # "Cord_Blood_3_3uM_IDTPCR",
            # "Cord_Blood_3_15uM_KapaPCR",
        ]
sample = "Cord_Blood_3_bufferR1_1"
# sample = "Cord_Blood_3_Ultrashear"
run = "/data/bbg/nobackup2/prominent/duplex_seq_tests/technology_tests/rosana_data/2025-11-03.tests/2025-11-04_deepUMIcaller"

# %% [markdown]
# ## All molecules

# %%
data = pd.read_csv(f"{run}/sortbamamfiltered/{sample}.sorted.read_counts_custom.tsv.gz",
                   sep="\s+",
                   header=None)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 data = pd.read_csv(f"{run}/sortbamamfiltered/{sample}.sorted.read_counts_custom.tsv.gz",
#       2                    sep="\s+",
#       3                    header=None)
#
# File ~/miniforge3/envs/notebooks_env/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/miniforge3/envs/notebooks_env/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/miniforge3/envs/notebooks_env/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniforge3/envs/notebooks_env/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/miniforge3/envs/notebooks_env/lib/python3.10/site-packages/pandas/io/common.py:765, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     761 if compression == "gzip":
#     762     if isinstance(handle, str):
#     763         # error: Incompatible types in assignment (expression has type
#     764         # "GzipFile", variable has type "Union[str, BaseBuffer]")
# --> 765         handle = gzip.GzipFile(  # type: ignore[assignment]
#     766             filename=handle,
#     767             mode=ioargs.mode,
#     768             **compression_args,
#     769         )
#     770     else:
#     771         handle = gzip.GzipFile(
#     772             # No overload variant of "GzipFile" matches argument types
#     773             # "Union[str, BaseBuffer]", "str", "Dict[str, Any]"
#    (...)
#     776             **compression_args,
#     777         )
#
# File ~/miniforge3/envs/notebooks_env/lib/python3.10/gzip.py:174, in GzipFile.__init__(self, filename, mode, compresslevel, fileobj, mtime)
#     172     mode += 'b'
#     173 if fileobj is None:
# --> 174     fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     175 if filename is None:
#     176     filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data/bbg/nobackup2/prominent/colon_duplex/iarc_pilot/deepUMI/2025-10-27_NOV69-70_plus_all_colon_DU5_set1/sortbamamfiltered/IA010_C_1_H_1.sorted.read_counts_custom.tsv.gz'

# %%
data.columns = ["count", "CHROM", "START", "END"]
data.head(20)
# Out:
#     count  CHROM      START        END
# 0    1236   chr3   93470438   93470438
# 1     891   chr5   49659827   49659827
# 2     782  chr17    7676342    7676342
# 3     757   chr3   93470690   93470690
# 4     738  chr21   10462758   10462758
# 5     722   chr6  160219097  160219097
# 6     683   chr3   93470633   93470633
# 7     581   chr6  160219054  160219054
# 8     526  chr22   41149021   41149021
# 9     480   chr3   93470550   93470550
# 10    472  chr21   10462759   10462759
# 11    467   chr3   93470447   93470447
# 12    450   chr3   93470570   93470570
# 13    401  chr21   10272418   10272418
# 14    387   chr3   93470672   93470672
# 15    377   chr3   93470361   93470361
# 16    376   chr3   93470484   93470484
# 17    376  chr21   10462757   10462757
# 18    375  chr21   10473590   10473590
# 19    368   chr3   93470546   93470546

# %%
# define a predefined set of bins to ensure consistency across samples, the last bin should include anything bigger than that
bins = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 60, 70, 80, 90, 100, 150, 200, 250, 300, 400, 500, 600, 1e6]

# %%
# use the previously defined bins to categorize the data
data['binned_count'] = pd.cut(data['count'], bins=bins, right=False)
# data['probability'] = data['binned_count'].value_counts(normalize=True)

# %%
count_data = data['binned_count'].value_counts(normalize=True).sort_index().reset_index()
count_data.columns = ['binned_count', 'probability']
count_data["percentage"] = count_data["probability"] * 100
count_data
# Out:
#           binned_count   probability  percentage
# 0           [0.0, 5.0)  9.981024e-01   99.810237
# 1          [5.0, 10.0)  6.469664e-04    0.064697
# 2         [10.0, 15.0)  2.822684e-04    0.028227
# 3         [15.0, 20.0)  2.241432e-04    0.022414
# 4         [20.0, 25.0)  1.794739e-04    0.017947
# 5         [25.0, 30.0)  1.379766e-04    0.013798
# 6         [30.0, 35.0)  1.069370e-04    0.010694
# 7         [35.0, 40.0)  7.812785e-05    0.007813
# 8         [40.0, 45.0)  5.722713e-05    0.005723
# 9         [45.0, 50.0)  4.174350e-05    0.004174
# 10        [50.0, 60.0)  5.589458e-05    0.005589
# 11        [60.0, 70.0)  3.114106e-05    0.003114
# 12        [70.0, 80.0)  1.856876e-05    0.001857
# 13        [80.0, 90.0)  1.103697e-05    0.001104
# 14       [90.0, 100.0)  7.705602e-06    0.000771
# 15      [100.0, 150.0)  1.329651e-05    0.001330
# 16      [150.0, 200.0)  3.157559e-06    0.000316
# 17      [200.0, 250.0)  9.994108e-07    0.000100
# 18      [250.0, 300.0)  4.490106e-07    0.000045
# 19      [300.0, 400.0)  3.186527e-07    0.000032
# 20      [400.0, 500.0)  7.242107e-08    0.000007
# 21      [500.0, 600.0)  2.896843e-08    0.000003
# 22  [600.0, 1000000.0)  1.013895e-07    0.000010

# %%
plt.figure(figsize=(8, 6))
sns.barplot(
    data=count_data,
    x="binned_count",
    y="percentage",
)
# plt.yscale("log")
plt.xticks(rotation=50, ha='right')
plt.xlabel("Read Count per Unique Cut Site")
plt.ylabel("Relative Frequency (log scale)")
plt.title(f"{sample}\nAll molecules\nDistribution of Read Counts per Unique Cut Site")
# plt.ylim(1e-9, 1)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Duplex molecules

# %%
data_duplex = pd.read_csv(f"{run}/sortbamduplexcons/{sample}.sorted.read_counts_custom.tsv.gz",
                   sep="\s+",
                   header=None)
data_duplex.columns = ["count", "CHROM", "START", "END"]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 data_duplex = pd.read_csv(f"{run}/sortbamduplexcons/{sample}.sorted.read_counts_custom.tsv.gz",
#       2                    sep="\s+",
#       3                    header=None)
#       4 data_duplex.columns = ["count", "CHROM", "START", "END"]
#
# File ~/miniforge3/envs/notebooks_env/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/miniforge3/envs/notebooks_env/lib/python3.10/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/miniforge3/envs/notebooks_env/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniforge3/envs/notebooks_env/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/miniforge3/envs/notebooks_env/lib/python3.10/site-packages/pandas/io/common.py:765, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     761 if compression == "gzip":
#     762     if isinstance(handle, str):
#     763         # error: Incompatible types in assignment (expression has type
#     764         # "GzipFile", variable has type "Union[str, BaseBuffer]")
# --> 765         handle = gzip.GzipFile(  # type: ignore[assignment]
#     766             filename=handle,
#     767             mode=ioargs.mode,
#     768             **compression_args,
#     769         )
#     770     else:
#     771         handle = gzip.GzipFile(
#     772             # No overload variant of "GzipFile" matches argument types
#     773             # "Union[str, BaseBuffer]", "str", "Dict[str, Any]"
#    (...)
#     776             **compression_args,
#     777         )
#
# File ~/miniforge3/envs/notebooks_env/lib/python3.10/gzip.py:174, in GzipFile.__init__(self, filename, mode, compresslevel, fileobj, mtime)
#     172     mode += 'b'
#     173 if fileobj is None:
# --> 174     fileobj = self.myfileobj = builtins.open(filename, mode or 'rb')
#     175 if filename is None:
#     176     filename = getattr(fileobj, 'name', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data/bbg/nobackup2/prominent/duplex_seq_tests/technology_tests/rosana_data/2025-11-03.tests/2025-11-04_deepUMIcaller/sortbamduplexcons/Cord_Blood_3_bufferR1_1.sorted.read_counts_custom.tsv.gz'

# %%
data_duplex.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 data_duplex.head()
#
# NameError: name 'data_duplex' is not defined

# %%
# use the previously defined bins to categorize the data
data_duplex['binned_count'] = pd.cut(data_duplex['count'], bins=bins, right=False)

count_data_duplex = data_duplex['binned_count'].value_counts(normalize=True).sort_index().reset_index()
count_data_duplex.columns = ['binned_count', 'probability']
count_data_duplex
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 # use the previously defined bins to categorize the data
# ----> 2 data_duplex['binned_count'] = pd.cut(data_duplex['count'], bins=bins, right=False)
#       4 count_data_duplex = data_duplex['binned_count'].value_counts(normalize=True).sort_index().reset_index()
#       5 count_data_duplex.columns = ['binned_count', 'probability']
#
# NameError: name 'data_duplex' is not defined

# %%
plt.figure(figsize=(8, 6))
sns.barplot(
    data=count_data_duplex,
    x="binned_count",
    y="probability"
)
plt.yscale("log")
plt.xticks(rotation=50, ha='right')
plt.xlabel("Read Count per Unique Cut Site")
plt.ylabel("Relative Frequency (log scale)")
plt.title(f"{sample}\nDuplex\nDistribution of Read Counts per Unique Cut Site")
plt.ylim(1e-9, 1)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 plt.figure(figsize=(8, 6))
#       2 sns.barplot(
# ----> 3     data=count_data_duplex,
#       4     x="binned_count",
#       5     y="probability"
#       6 )
#       7 plt.yscale("log")
#       8 plt.xticks(rotation=50, ha='right')
#
# NameError: name 'count_data_duplex' is not defined

# %% [markdown]
# ## UMI counts

# %%
# umi_counts_data = pd.read_table(f"{run}/collectduplexseqmetricsontarget/{sample}_chr1.on_target.duplex_seq_metrics.umi_counts.txt")
umi_counts_data = pd.read_table(f"{run}/collectduplexseqmetricsontarget/{sample}.on_target.duplex_seq_metrics.umi_counts.txt")
umi_counts_data = umi_counts_data.sort_values("fraction_raw_observations", ascending = False).reset_index(drop=True)
umi_counts_data["cummulative_fraction"] = umi_counts_data["fraction_raw_observations"].cumsum()
umi_counts_data.head()
# Out:
#    umi  raw_observations  raw_observations_with_errors  unique_observations  \
# 0  AAT           2938378                             0               460782
# 1  CCT           2623326                             0               426328
# 2  ATA           2605815                             0               411504
# 3  TTA           2550628                             0               396723
# 4  TTT           2520883                             0               393887
#
#    fraction_raw_observations  fraction_unique_observations  \
# 0                   0.026431                      0.025781
# 1                   0.023597                      0.023853
# 2                   0.023440                      0.023024
# 3                   0.022943                      0.022197
# 4                   0.022676                      0.022038
#
#    cummulative_fraction
# 0              0.026431
# 1              0.050028
# 2              0.073468
# 3              0.096411
# 4              0.119087

# %%
# major_freq = umi_counts_data[umi_counts_data["cummulative_fraction"] <= 0.99]
# minor_freq_df = umi_counts_data[umi_counts_data["cummulative_fraction"] > 0.99].sum()

major_freq_df = umi_counts_data.iloc[:100,:]
minor_freq_df = umi_counts_data.iloc[100:,:]
minor_freq = minor_freq_df.sum()
minor_freq["umi"] = str(len(minor_freq_df)) + 'umis'
minor_freq["cummulative_fraction"] = 1
minor_freq
# Out:
# umi                             0umis
# raw_observations                    0
# raw_observations_with_errors        0
# unique_observations                 0
# fraction_raw_observations         0.0
# fraction_unique_observations      0.0
# cummulative_fraction                1
# dtype: object

# %%
merged_umis = pd.concat([major_freq_df, minor_freq.to_frame().T], ignore_index=True)
merged_umis = merged_umis.reset_index()
merged_umis.head()
# Out:
#    index  umi raw_observations raw_observations_with_errors  \
# 0      0  AAT          2938378                            0
# 1      1  CCT          2623326                            0
# 2      2  ATA          2605815                            0
# 3      3  TTA          2550628                            0
# 4      4  TTT          2520883                            0
#
#   unique_observations fraction_raw_observations fraction_unique_observations  \
# 0              460782                  0.026431                     0.025781
# 1              426328                  0.023597                     0.023853
# 2              411504                   0.02344                     0.023024
# 3              396723                  0.022943                     0.022197
# 4              393887                  0.022676                     0.022038
#
#   cummulative_fraction
# 0             0.026431
# 1             0.050028
# 2             0.073468
# 3             0.096411
# 4             0.119087

# %%
# plot cumsumative distribution of duplex UMIs (fraction_raw_observations)
sns.lineplot(data=merged_umis, x="index", y="fraction_raw_observations")
plt.xlabel("UMI Rank")
plt.ylabel("Fraction of Raw Observations")
plt.title(f"{sample}\nCumulative Distribution of UMIs")
plt.show()

# %% [markdown]
# ## Duplex UMI counts

# %%
# umi_counts_data = pd.read_table(f"{run}/collectduplexseqmetricsontarget/{sample}_chr1.on_target.duplex_seq_metrics.umi_counts.txt")
umi_counts_data = pd.read_table(f"{run}/collectduplexseqmetricsontarget/{sample}.on_target.duplex_seq_metrics.duplex_umi_counts.txt")
umi_counts_data = umi_counts_data.sort_values("fraction_raw_observations", ascending = False).reset_index(drop=True)
umi_counts_data["cummulative_fraction"] = umi_counts_data["fraction_raw_observations"].cumsum()
umi_counts_data.head()
# Out:
#                  umi  raw_observations  raw_observations_with_errors  \
# 0  AAGACCTT-AGAGTCCT             55434                          1258
# 1  AGAGTCCT-GCACATCC             55094                          1227
# 2  AGAGTCCT-AAGACCTT             54465                          1194
# 3  AAGACCTT-GCACATCC             54291                          1336
# 4  GCACATCC-AGAGTCCT             53381                          1273
#
#    unique_observations  fraction_raw_observations  \
# 0                 4574                   0.000442
# 1                 4370                   0.000439
# 2                 4579                   0.000434
# 3                 4343                   0.000433
# 4                 4336                   0.000426
#
#    fraction_unique_observations  fraction_unique_observations_expected  \
# 0                      0.000410                               0.000407
# 1                      0.000392                               0.000384
# 2                      0.000410                               0.000407
# 3                      0.000389                               0.000380
# 4                      0.000388                               0.000384
#
#    cummulative_fraction
# 0              0.000442
# 1              0.000881
# 2              0.001315
# 3              0.001748
# 4              0.002174

# %%
for threshold in [0.95, 0.99, 0.995, 0.999]:
    major_freq_df = umi_counts_data[umi_counts_data["cummulative_fraction"] <= threshold]
    minor_freq_df = umi_counts_data[umi_counts_data["cummulative_fraction"] > threshold]
    print(f"Threshold: {threshold}: major: {len(major_freq_df)}, minor: {len(minor_freq_df)}")
    print()


major_freq_df = umi_counts_data[umi_counts_data["cummulative_fraction"] <= 0.999]
minor_freq_df = umi_counts_data[umi_counts_data["cummulative_fraction"] > 0.999]
# major_freq_df = umi_counts_data.iloc[:100000,:]
# minor_freq_df = umi_counts_data.iloc[100000:,:]

print(len(major_freq_df), len(minor_freq_df))

minor_freq = minor_freq_df[['raw_observations', 'raw_observations_with_errors',
                            'unique_observations', 'fraction_raw_observations',
                            'fraction_unique_observations', 'fraction_unique_observations_expected',]].sum()
minor_freq["umi"] = str(len(minor_freq_df)) + ' umis'
minor_freq["cummulative_fraction"] = 1
minor_freq
# Out:
# Threshold: 0.95: major: 7772, minor: 387041
#
# Threshold: 0.99: major: 9102, minor: 385711
#
# Threshold: 0.995: major: 33938, minor: 360875
#
# Threshold: 0.999: major: 269747, minor: 125066
#
# 269747 125066
# raw_observations                            125066.0
# raw_observations_with_errors                     0.0
# unique_observations                         125066.0
# fraction_raw_observations                   0.000997
# fraction_unique_observations                0.011205
# fraction_unique_observations_expected       0.003728
# umi                                      125066 umis
# cummulative_fraction                               1
# dtype: object

# %%
merged_umis = pd.concat([major_freq_df, minor_freq.to_frame().T], ignore_index=True)
merged_umis = merged_umis.reset_index()
merged_umis.head()
# Out:
#    index                umi raw_observations raw_observations_with_errors  \
# 0      0  AAGACCTT-AGAGTCCT            55434                         1258
# 1      1  AGAGTCCT-GCACATCC            55094                         1227
# 2      2  AGAGTCCT-AAGACCTT            54465                         1194
# 3      3  AAGACCTT-GCACATCC            54291                         1336
# 4      4  GCACATCC-AGAGTCCT            53381                         1273
#
#   unique_observations fraction_raw_observations fraction_unique_observations  \
# 0                4574                  0.000442                      0.00041
# 1                4370                  0.000439                     0.000392
# 2                4579                  0.000434                      0.00041
# 3                4343                  0.000433                     0.000389
# 4                4336                  0.000426                     0.000388
#
#   fraction_unique_observations_expected cummulative_fraction
# 0                              0.000407             0.000442
# 1                              0.000384             0.000881
# 2                              0.000407             0.001315
# 3                               0.00038             0.001748
# 4                              0.000384             0.002174

# %%
# plot cumsumative distribution of duplex UMIs (fraction_raw_observations)
sns.histplot(data=merged_umis, x="fraction_raw_observations", bins=500)
plt.xlabel("Fraction of Raw Observations")
plt.title(f"{sample}\n Histogram of Duplex UMIs by Fraction of Raw Observations")
# plt.xscale("log")
plt.yscale("log")
plt.show()

# %%
# plot cumsumative distribution of duplex UMIs (fraction_raw_observations)
sns.histplot(data=merged_umis, x="fraction_raw_observations", bins=500)

plt.xlabel("Fraction of Raw Observations")
plt.title(f"{sample}\n Histogram of Duplex UMIs by Fraction of Raw Observations")

plt.yscale("log")
plt.show()

# %%
# plot cumsumative distribution of duplex UMIs (fraction_raw_observations)
sns.lineplot(data=merged_umis, x="index", y="fraction_raw_observations")
plt.xlabel("Duplex UMI Rank")
plt.ylabel("Fraction of Raw Observations")
plt.title(f"{sample}\nCumulative Distribution of Duplex UMIs")
plt.show()

# %%
# plot cumsumative distribution of duplex UMIs (fraction_raw_observations)
sns.lineplot(data=merged_umis, x="index", y="fraction_raw_observations")
plt.xlabel("Duplex UMI Rank")
plt.ylabel("Fraction of Raw Observations")
plt.title(f"{sample}\nCumulative Distribution of Duplex UMIs")
plt.show()
