# %% [markdown]
# ## Extended Data Figure 6: Quality control of mutation density values across genes and samples
#
# This script is used to generate the following plots:
#
# **d** Distribution of non-protein affecting mutation density.
#
# **e** Comparison of missense and truncatinf dN/dS values at sample level.

# %%
# --- 1. Setup: imports -------------------------------------------
import pandas as pd
import os, sys
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from itertools import combinations

# from scipy.stats import linregress
# from matplotlib_venn import venn2
# from tqdm import tqdm
# tqdm.pandas()

# %%
sys.path.append('../../../') 
from consensus_variables import *

# %%
# --- 2. Read data -------------------------------------------
# maf_df = pd.read_table(maf_file)
all_omegas = pd.read_table("../data/all_omegas.tsv")
all_omegas_gloc = pd.read_table("../data/all_omegas_global_loc.tsv")

# %%
# --- 2. Preprocessing -------------------------------------------
# Filter all omega values to include only P19 samples, and  missense and truncating variants
per_sample_o = all_omegas[~(all_omegas["gene"].str.contains("--"))
                            & (all_omegas["sample"].str.startswith("P19"))
                            & (all_omegas["impact"].isin(["missense", "truncating"]))
                            ]

# %%
# Filter all omega global values to include only P19 samples, and  missense and truncating variants
per_sample_ogloc = all_omegas_gloc[~(all_omegas_gloc["gene"].str.contains("--"))
                                    & (all_omegas_gloc["sample"].str.startswith("P19"))
                                    & (all_omegas_gloc["impact"].isin(["missense", "truncating"]))
                                    ]

# %%
per_sample_o.shape, per_sample_ogloc.shape
# Out:
# ((1531, 8), (2067, 8))

# %%
per_sample_o.groupby("impact").size(), per_sample_ogloc.groupby("impact").size()
# Out:
# (impact
#  missense      831
#  truncating    700
#  dtype: int64,
#  impact
#  missense      1182
#  truncating     885
#  dtype: int64)

# %%
# --- 3. Plot coverage per sample -------------------------------------------
omega_counts = per_sample_o.groupby("impact").size()
ogloc_counts = per_sample_ogloc.groupby("impact").size()

counts = pd.DataFrame({
    'Category': ['dN/dS\nmissense', 'dN/dS\ntruncating'],
    'local': [ omega_counts["missense"],  omega_counts["truncating"]],
    'globalloc': [ ogloc_counts["missense"],  ogloc_counts["truncating"]]
})


plt.figure(figsize=(2, 2))
counts.set_index('Category').plot(kind='bar', ax=plt.gca())
plt.xticks(rotation=0)
plt.title('Coverage of sample x gene combinations\nomega-local vs omega-globalloc')
plt.ylabel('Number of\nsample X gene combinations')
plt.xlabel("Consequence type")
plt.savefig("../plots/dnds_coverage_comparison.pdf", dpi=300, bbox_inches="tight")
plt.show()

# %%
merged_omegas = per_sample_o.merge(per_sample_ogloc, on=["gene", "sample", "impact", "mutations"], suffixes=("_o", "_ogloc"))
merged_omegas
# Out:
#            gene           sample      impact  mutations     dnds_o  \
# 0         FGFR3  P19_0038_BDO_01    missense          3   0.684375
# 1         RBM10  P19_0038_BDO_01    missense         13   1.674988
# 2         RBM10  P19_0038_BDO_01  truncating          4   3.632910
# 3        CDKN1A  P19_0038_BDO_01    missense          2   0.841797
# 4        CDKN1A  P19_0038_BDO_01  truncating          1   3.440625
# ...         ...              ...         ...        ...        ...
# 1526      KDM6A  P19_0002_BDO_01  truncating         32  18.096875
# 1527     CREBBP  P19_0002_BDO_01    missense         41   3.207813
# 1528     CREBBP  P19_0002_BDO_01  truncating         12   8.040625
# 1529  ALL_GENES  P19_0002_BDO_01    missense        403   2.235132
# 1530  ALL_GENES  P19_0002_BDO_01  truncating        210  10.581250
#
#           pvalue_o    lower_o    upper_o  dnds_ogloc  pvalue_ogloc  \
# 0     4.847888e-01   0.170032   1.783008    1.024901      0.966406
# 1     8.967042e-02   0.916475   2.782776    1.038306      0.894183
# 2     3.416437e-02   1.121816   8.536475    2.250439      0.154795
# 3     8.036910e-01   0.139968   2.614258    0.996881      0.995877
# 4     3.055273e-01   0.195937  15.299146    4.071777      0.255065
# ...            ...        ...        ...         ...           ...
# 1526  0.000000e+00  12.303975  25.676221   27.718750      0.000000
# 1527  0.000000e+00   2.301401   4.344287    2.318750      0.000004
# 1528  1.192093e-07   4.250782  13.756567    5.812497      0.000003
# 1529  0.000000e+00   1.971115   2.531763    2.229688      0.000000
# 1530  0.000000e+00   8.859163  12.597241   10.377930      0.000000
#
#       lower_ogloc  upper_ogloc
# 0        0.254805     2.670409
# 1        0.567836     1.724341
# 2        0.694822     5.289380
# 3        0.166128     3.091608
# 4        0.232128    18.094604
# ...           ...          ...
# 1526    18.850901    39.338623
# 1527     1.663777     3.140283
# 1528     3.072744     9.944577
# 1529     1.966316     2.525098
# 1530     8.683902    12.358521
#
# [1531 rows x 12 columns]

# %%
merged_omegas["dnds_o"].min()
# Out:
# np.float64(0.1056579589843742)

# %%
# --- 4. Plot Comparison of missense and truncating values -------------------------------------------
plt.figure(figsize=(2, 2))
sns.scatterplot(data=merged_omegas,
                x="dnds_o",
                y="dnds_ogloc",
                alpha = 0.7,
                hue="gene",
                legend = False,
                s = 5
                )
plt.xlim(0.09, 600)
plt.ylim(0.09, 600)

# add x == y line
lims = [0.09, 600]
plt.plot(lims, lims, 'k--', alpha=0.75, zorder=0)

plt.xscale("log")
plt.yscale("log")
plt.xlabel("dN/dS (local)")
plt.ylabel("dN/dS (global loc)")
plt.title("Comparison of missense and truncating\ndN/dS values at sample level")
plt.savefig("../plots/dnds_comparison.pdf", dpi=300, bbox_inches="tight")
plt.show()

# %%
plt.figure(figsize=(4, 4))
upper_lim = 20
sns.displot(data = merged_omegas[(merged_omegas["dnds_o"] < upper_lim)
                                 & (merged_omegas["dnds_ogloc"] < upper_lim)
                                 ],
                x="dnds_o",
                y="dnds_ogloc",
                binwidth=(.2, .2),
                )
# # add x == y line
# lims = [0.09, 600]
# plt.plot(lims, lims, 'k--', label = "x = y", alpha=0.75, zorder=0)

# plt.xscale("log")
# plt.yscale("log")
# plt.xlabel("dN/dS")
# plt.ylabel("dN/dS (global loc)")
# plt.title("Comparison of missense and truncating\ndN/dS values at sample level")
# plt.legend()
# plt.savefig("dnds_comparison.pdf", dpi=300, bbox_inches="tight")
plt.show()
